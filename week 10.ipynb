# %% [markdown]
# # Week – 10: AI Application-Early Image Processing
# Implement a basic image enhancement technique, such as histogram equalization or contrast stretching. Explain how
# this operation improves image quality.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('week 10.png', cv2.IMREAD_GRAYSCALE)

# Apply Histogram Equalization
equalized_image = cv2.equalizeHist(image)

# Display Original and Enhanced Images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Equalized Image")
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# ### **Explanation of the Histogram Equalization Program for Lung Cancer Image**
#
# You used a **lung cancer image** as a reference to apply **Histogram Equalization**, which helps improve the contrast and visibility of details in medical images. Below is a step-by-step breakdown of the program:
#
# ---
#
# ### **Step 1: Import Required Libraries**
# ```python
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# ```
# - `cv2`: Used for reading and processing images.
# - `numpy`: Handles numerical operations.
# - `matplotlib.pyplot`: Displays images.
#
# ---
#
# ### **Step 2: Load the Lung Cancer Image in Grayscale**
# ```python
# image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)
# ```
# - Reads the **lung cancer X-ray or CT scan**.
# - `cv2.IMREAD_GRAYSCALE` converts the image to **black & white** for analysis.
#
# ---
#
# ### **Step 3: Apply Histogram Equalization**
# ```python
# equalized_image = cv2.equalizeHist(image)
# ```
# - Enhances contrast by redistributing pixel intensity.
# - Helps make **tumor regions or abnormalities more visible**.
#
# ---
#
# ### **Step 4: Display the Original and Enhanced Images**
# ```python
# plt.figure(figsize=(10, 5))
#
# plt.subplot(1, 2, 1)
# plt.title("Original Image")
# plt.imshow(image, cmap='gray')
# plt.axis('off')
#
# plt.subplot(1, 2, 2)
# plt.title("Equalized Image")
# plt.imshow(equalized_image, cmap='gray')
# plt.axis('off')
#
# plt.show()
# ```
# - Creates a **side-by-side comparison**.
# - **Left:** Original Lung Cancer Image.
# - **Right:** Enhanced Image with **better contrast and visibility**.
#
# ---
#
# ### **🔹 How Does This Help in Lung Cancer Detection?**
# ✅ **Enhances Contrast** – Highlights **tumor regions** that might be faint.
# ✅ **Improves Visibility** – Helps doctors **detect abnormalities** easily.
# ✅ **Medical Applications** – Used in **CT scans, MRIs, and X-rays**.
#
# Would you like to apply other enhancements, such as **adaptive histogram equalization** for even better results? 🚀
